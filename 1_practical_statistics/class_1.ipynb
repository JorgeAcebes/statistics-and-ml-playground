# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 

print('Imported libraries')
# Out:
# Imported libraries

# %% [markdown]
# # Data Organization and Visualization

# %% [markdown]
# ## Tables

# %%
# Columnas: features

fruits = {'type': ['Apple', 'Strawberry', 'Banana'], 'peel': [1, 0, 1], 'weight (g)': [200, 15, 150]}
pd_fruits = pd.DataFrame(data=fruits) # Generates a Data Frame (table) from our dict

pd_fruits
# Out:
#          type  peel  weight (g)
# 0       Apple     1         200
# 1  Strawberry     0          15
# 2      Banana     1         150

# %% [markdown]
# ### Bigger Datasets

# %%
from sklearn.datasets import fetch_openml
